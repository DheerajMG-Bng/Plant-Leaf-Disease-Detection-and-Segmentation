# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/f6a20939-1617-49f7-a7a4-1dde2020426b___JR_B.Spot_3365.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/d7ab068b-694f-4a0e-8e72-ad065d9e7022___NREC_B.Spot_1834.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/fd733c73-855b-49df-87cd-628bcd5e87a7___NREC_B.Spot_9240.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/648a0b23-8a55-4530-a0a0-b04882298d24___NREC_B.Spot_1839.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/3c237d3f-7242-4009-a08a-b4eb7cd662fc___NREC_B.Spot_1969.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/525555a6-c09c-4551-8b9d-d2a8050f474d___JR_B.Spot_3355.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/836b4b9e-85d5-47bc-ad93-9ab31b07be3d___JR_B.Spot_3361.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/ab5f2fed-0c46-46ad-b63a-86760db73e6a___JR_B.Spot_3354.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/8048788f-facf-475b-8728-4724d98f4df9___JR_B.Spot_3216.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/57337b7c-f7b3-4ed0-a249-921df1351cf1___JR_B.Spot_3243.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/ca536e69-ebc0-4a82-8bca-c074f9399885___JR_B.Spot_8986.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/6565f5ba-8e68-4d1a-b267-b12bfd73f3ef___JR_B.Spot_3252.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/9e501de6-b39a-4a9c-b5f7-f55a246c02b6___NREC_B.Spot_9207.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/abc52078-90cf-426a-8ed8-602a35243d3e___NREC_B.Spot_9221.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/816dee9f-b43f-42da-b0c9-3fb8b29d511d___NREC_B.Spot_9182.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/a6dc1321-f6f9-48ae-be94-5ce894d15e89___NREC_B.Spot_9058.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/caa7bde5-3d2d-484c-8c71-607b4b1041f8___JR_B.Spot_8870.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/d6ec81e9-4a00-4b62-9e45-0d4fde6a5c68___NREC_B.Spot_1850.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/697e19e9-b11b-4bc8-884b-e25d432b90f6___NREC_B.Spot_9206.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/05c6ea65-cce4-43da-b57b-a45321b0e51b___NREC_B.Spot_9048.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/6a457821-e634-425c-90f0-a4bbd76b5722___JR_B.Spot_3159.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/b76271aa-ca0b-44ac-a6f9-379ef70ef443___JR_B.Spot_3389.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/3d0ebe4c-591f-490f-b389-cd8f424acbba___JR_B.Spot_9041.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/ac6e6cad-2932-4af0-ad68-fdf044eecc8c___NREC_B.Spot_1796.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/4c34e3ed-523a-414d-b28d-52078277cb67___NREC_B.Spot_9174.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/924c8aa8-14ac-4b67-847b-900965799792___JR_B.Spot_3169.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/b9a94a36-2bdb-48a3-80eb-858a97ddba5b___JR_B.Spot_9080.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/c93e971c-7419-410e-8ea3-7094610d11e0___NREC_B.Spot_9081.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/4f49f8c2-d091-40d0-b85c-db10099b3caa___NREC_B.Spot_9171.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/1b8d3e98-43d9-441d-93ef-a359e6e9ddc2___NREC_B.Spot_9052.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/96f532cf-0f68-421f-824e-4bc6e1dc6925___JR_B.Spot_3168.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/5f4f7469-3f1c-4f29-a5f7-68f2e57ce261___JR_B.Spot_9030.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/ebe12503-1abc-4e09-9eee-3180b67c29f4___JR_B.Spot_8849.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/796c804e-6764-4497-8ded-dc7ac3f0112c___JR_B.Spot_9007.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/11a23270-53e7-41b6-8c79-91caeaf9cfa6___JR_B.Spot_9050.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/ff81e22a-09bf-49bd-b45a-c75606cd113b___NREC_B.Spot_1811.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/42ef264d-f255-4674-885a-0921a0e7f649___JR_B.Spot_9022.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/46372226-cfbe-4206-951b-93b8b411d2e7___JR_B.Spot_8890.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/64ed4b17-84ad-4088-b079-c02eceef5e7e___NREC_B.Spot_1958.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/ee7addf1-7941-463f-899e-3c38cafea9df___JR_B.Spot_9002.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/b3085525-974e-4d75-99a4-7d18e06e13f6___JR_B.Spot_3317.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/db56c75b-22ed-473b-91ce-814d78d38574___JR_B.Spot_3325.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/b82e0746-97b5-4be9-90a7-ac2b2121428c___JR_B.Spot_9073.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/799cf6ba-63c7-442c-b33a-4b1d31b00eac___NREC_B.Spot_1852.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/cd35e968-1e90-4fc9-a0d1-574b89bc3019___NREC_B.Spot_9082.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/f92689ca-b5db-4a0a-b865-a69ba215922f___JR_B.Spot_9040.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/5640520e-087c-41ae-b462-c30d8aa51aab___JR_B.Spot_8914.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/99a07bbb-44a9-48b2-ae4e-306e4282802c___NREC_B.Spot_9064.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/994dd8b0-a87e-485a-be38-cb01b8843e44___JR_B.Spot_8857.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/bc76d04a-056a-4fa4-a3de-2d848101631a___JR_B.Spot_9089.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/e1a8a7b1-5e9a-4da0-a894-9d83821b0d01___NREC_B.Spot_9170.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/f7b2c446-72fe-4990-91cc-8764e819ad3b___JR_B.Spot_9004.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/c169d60e-df5f-4b67-b58b-b07b7d20e5bc___JR_B.Spot_8885.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/a664ab66-84d0-4bcf-b771-46db16372dda___NREC_B.Spot_1970.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/11e6ce0a-8511-485a-b22c-21b978d28e5e___JR_B.Spot_3383.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/39875cb8-3958-46b9-a9dc-f810f353af5a___JR_B.Spot_3321.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/c94ae9a2-f5b0-4da4-9bd1-c66ef5b0ad74___JR_B.Spot_3167.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/bcbca73b-22a6-40e4-ba78-8bfe313665ff___JR_B.Spot_8894.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/da80eee6-ceb1-4d53-b783-3e865087ed26___JR_B.Spot_3314.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/7b7b589f-1bb8-43fb-8fa0-b510e200dd99___JR_B.Spot_9061.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/162a3375-31e6-48f4-9b78-ab35054fb86c___JR_B.Spot_3397.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/3a03526d-0bf4-4898-9f0f-8a9c31afd3eb___JR_B.Spot_3380.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/a663a181-328d-4991-b427-614f3bdf14b8___JR_B.Spot_9063.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/01613cd0-d3cd-4e96-945c-a312002037bf___JR_B.Spot_3262.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/7e08147f-d930-4854-a1de-300e53834534___JR_B.Spot_3127.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/ead27319-4073-490e-80a0-08e916bbc1f2___JR_B.Spot_9084.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/969f1458-b7a9-4880-9759-05b0005c978e___JR_B.Spot_8978.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/260e0075-466d-4aa2-8ad6-825cce898cdb___JR_B.Spot_9065.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/c9e13908-bce6-4ad7-831f-a4a408cabf72___JR_B.Spot_3198.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/2254cc78-9169-4f14-9ab9-d9d3949a5f69___JR_B.Spot_3295.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/0576dd21-3958-46a5-ab99-f9865371bd1a___NREC_B.Spot_1957.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/e71b39c4-8007-46c0-a925-adaf30e71fd1___JR_B.Spot_9054.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/0022d6b7-d47c-4ee2-ae9a-392a53f48647___JR_B.Spot_8964.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/3ddc56a6-7b13-43ae-841a-c6f6818d001b___JR_B.Spot_3190.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/424602ec-36eb-425c-8bd9-73be3e544cf2___NREC_B.Spot_9251.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/ca89aafd-ce2f-4eaf-96ab-362bf91311b9___JR_B.Spot_8883.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/538ad66b-39cb-4972-8ad7-8ebf1964f782___JR_B.Spot_9001.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/eb2fd423-38f8-42b5-88bf-4fdc81adba95___JR_B.Spot_8952.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/61764b09-9bb9-44b3-af94-d3408045b7c3___NREC_B.Spot_1891.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/1044c742-39a0-4b1a-984f-3cb2bdeda94b___NREC_B.Spot_9219.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/3d6a3d51-8a9f-42ff-b4bf-299778c3e0a8___JR_B.Spot_3184.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/3d203d3a-3614-4ddf-9956-0c6a12208c7e___JR_B.Spot_3391.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/12342367-f62b-40d0-897b-77bd1edbd3d1___JR_B.Spot_3199.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/8631f961-c7d1-4ce8-b777-44aa9fbdb24a___JR_B.Spot_3180.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/f04c0c6c-ac82-4ac1-abbb-336630ea6363___JR_B.Spot_3129.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/731d3112-8dfa-4ce0-b27e-6a0cdb661a6d___NREC_B.Spot_9232.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/da982561-a660-482e-bccc-72bdff79e454___NREC_B.Spot_1966.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/b810580c-a559-4c50-8378-0ec894de8a36___NREC_B.Spot_1838.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/77025edb-ef4e-4a72-a8d8-f4c12d43d91c___NREC_B.Spot_9083.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/d28d81c9-d06f-4e9c-b9f6-8347273320b6___NREC_B.Spot_1983.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/9c23ddea-18e9-4b79-b890-77c6077d8966___JR_B.Spot_3195.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/da357d28-8de5-4d71-9c44-3a5ea8dbb476___NREC_B.Spot_1910.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/58e3b37c-5192-4a03-9f8a-da00330c529a___NREC_B.Spot_9237.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/e348be18-797b-48ab-856a-3e58bde6c874___JR_B.Spot_3229.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/b27e9697-adcc-41bb-becb-7bc34bbf3cee___JR_B.Spot_3264.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/d2b4564a-7428-4f27-ae26-d30c9d013cd8___JR_B.Spot_8917.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/1fca0f2b-857b-4cef-9218-42b1bdd92d00___JR_B.Spot_8969.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/cec0354e-5caf-4eb7-9fa5-a7b07ac1b644___JR_B.Spot_9070.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/146d24cd-0c7e-458b-9f82-7b27525b04e4___JR_B.Spot_3329.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/28c448aa-4d2c-4a96-baf0-e7ed99ae2495___JR_B.Spot_3385.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/d2e908d9-71d4-451a-b77d-6152c4a91957___JR_B.Spot_3175.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/8a76c7e0-7da2-41c0-8167-75da69445d0d___JR_B.Spot_3143.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/c21c9506-e89f-4ff4-b9f1-7a666de39f50___NREC_B.Spot_9078.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/bfc55b79-3f3b-4884-b5ec-b66c02b9cabb___JR_B.Spot_3260.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/1d89d58f-09d2-42ee-a9dc-11e51d0a1635___JR_B.Spot_8826.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/5f7e373c-1bcb-4730-b55d-d0caf375bb0b___JR_B.Spot_8948.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/12f47cff-1a75-47ec-99d2-01720786e478___NREC_B.Spot_1859.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/33952a4a-ef41-4eff-9a2a-35bbea1b6686___JR_B.Spot_3200.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/36aa1467-175d-42d0-8da3-99e8ffd06fbe___NREC_B.Spot_1905.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/4434e395-4f3d-435d-9101-ece6be005fd6___JR_B.Spot_8928.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/b34482ab-b18b-4d93-b3f6-9143a7e5c9b0___JR_B.Spot_3394.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/fde20c63-cca2-4edb-9e6c-77b3a7f95cbd___JR_B.Spot_3400.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/5f1731b8-21ee-43d8-a019-8591428f4e3e___JR_B.Spot_9003.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/3a041cb2-cd43-4fcf-8f84-f559d40f1bd8___JR_B.Spot_9101.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/3b3fcf17-b337-4548-b27f-f2b501c035c0___NREC_B.Spot_1942.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/7f07dc8d-dc42-4b4a-89a8-f2d2e10bdba7___NREC_B.Spot_9167.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/3df25df9-50f7-4430-8853-0ab2d3ca2579___JR_B.Spot_9083.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/952535f2-d337-434c-90e4-0be62ad20db9___JR_B.Spot_3348.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/1b589f92-a658-4e58-96de-db41acc411ce___JR_B.Spot_3239.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/bac5f227-64b0-4064-9716-611dd35c2897___JR_B.Spot_3103.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/88567f21-a54a-44bb-a572-e3b1c14c3832___JR_B.Spot_3156.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/b22693c9-a87d-4ffa-82b1-0218e1b966be___JR_B.Spot_3277.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/12c9c98f-afc9-4c12-8a97-007e5a40712a___NREC_B.Spot_9053.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/65de6d37-4ea5-4ac7-af08-a974eb5b501a___NREC_B.Spot_9106.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/0d2635e7-df23-4ceb-b3ba-3af50bb58357___NREC_B.Spot_1874.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/b928cffb-f480-44a8-9b09-70ef158fdc7c___JR_B.Spot_3155.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/490afec2-acdf-4b61-b137-43d43285817c___JR_B.Spot_8949.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/af2e0582-8683-4b26-a3e2-0e17b2de09c6___NREC_B.Spot_1848.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/f69531dd-6acc-4af1-afb1-b6970e153b6a___NREC_B.Spot_9248.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/5d17a185-67fe-465f-81b9-35d936f24f99___JR_B.Spot_3181.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/36223df9-bc20-4672-8938-6f1f60fb4a0e___NREC_B.Spot_1873.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/820a7257-dc1d-46af-ba5a-b006c35fc1b1___JR_B.Spot_3116.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/18df58d7-c6ac-48e5-8cb0-596b70252a8e___NREC_B.Spot_9153.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/9cee73cb-272f-4121-b82d-c8c2b3ca71a0___NREC_B.Spot_1813.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/475f941c-242c-42e1-9149-ace60e32b931___NREC_B.Spot_9208.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/2cdea224-6f10-4a3d-a3f1-1debd1a42640___JR_B.Spot_8926.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/c868e0ed-12df-48d5-9ad8-e924a0c7ccbf___NREC_B.Spot_1986.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/c4791388-b93b-4cad-9ee8-e243c2847f0c___JR_B.Spot_9024.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/e05d9bf6-8d96-4fb5-8ea4-b9bab9e9bb8f___JR_B.Spot_3142.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/e5a83007-3ed6-4621-ac3f-75337614f490___NREC_B.Spot_9209.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/3da16030-36bd-4866-826f-70945a9f8b60___JR_B.Spot_8934.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/a61f0df0-86c7-47dc-9d44-36918ce63d1a___NREC_B.Spot_1925.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/d2a4d03b-3234-4ce5-9fcb-3d6e5fddae51___NREC_B.Spot_1894.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/4f539b76-13f8-43ab-a630-0cc6b1461bc9___JR_B.Spot_3381.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/bf437495-ab1b-459e-8173-6619a07ee8c6___JR_B.Spot_3139.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/d8e201e5-870e-4985-b2d7-f0dc80ab96b0___JR_B.Spot_8892.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/144ae14f-dbf4-4dfa-9d47-98fb33009a48___JR_B.Spot_3364.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/7c719504-0327-4be0-b898-b50760a26de6___JR_B.Spot_3310.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/97fa8b63-1a92-4760-802c-2acfecc67e65___JR_B.Spot_8827.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/09ae534a-e931-4f83-8545-cf330dfebae9___NREC_B.Spot_9210.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/f47251cd-5d05-4d98-847c-4e1ae180333a___NREC_B.Spot_1965.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/eabaa1bb-a866-4670-887e-3d9897c31fae___JR_B.Spot_3274.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/17737361-6967-452a-ac5d-efebaa1d8a35___NREC_B.Spot_9127.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/dd2bf52d-685d-4feb-ac7e-846cbd29d9c3___JR_B.Spot_8891.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/12c953a0-bd3e-45d0-aaea-5139f5d63e01___JR_B.Spot_8863.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/176a9f0a-b815-4e4d-88d4-0960610f723b___NREC_B.Spot_1820.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/1cce64aa-6f9f-4ce1-b319-dbc4a012b240___JR_B.Spot_8998.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/9ef2ed30-14d6-4711-92b3-9a9fbf435c9f___NREC_B.Spot_9049.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/a47d3b9e-eda3-4de2-b8a9-f5505e28d309___JR_B.Spot_3118.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/2adcf097-e515-49f1-9716-c0d06d8b52b4___NREC_B.Spot_1933.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/f2e21841-962e-4044-bb5d-efd8af95df74___NREC_B.Spot_1893.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/315668fd-452d-43c1-8a63-e3b4d3d634a7___JR_B.Spot_3097.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/3f436076-8f23-46e8-a730-08bffac34ea4___JR_B.Spot_3379.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/7642e377-d6af-4092-ae84-a1fa10a7f1e1___NREC_B.Spot_1914.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/1219f26f-a23a-4c2a-99f0-407fc785c74a___JR_B.Spot_3332.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/378ed86f-f435-44e8-93b3-3e05aa569492___JR_B.Spot_8864.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/42b527a8-b3a7-47ae-981b-91727cd2f7e5___JR_B.Spot_3306.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/afc76c77-fd2d-4b7f-b1ad-14ba4d5fe297___NREC_B.Spot_9113.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/ffa3b1df-49c6-4fd2-9ec5-1ca5eb175797___JR_B.Spot_3254.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/895a07dd-367e-4e79-8730-27bec5d951e9___JR_B.Spot_3259.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/0719e8e8-c1ae-4d5a-b29c-dbadc36d13f3___NREC_B.Spot_1947.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/35b1d344-1bb9-4976-9ba2-de290dd167dd___NREC_B.Spot_9056.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/179067a6-1012-4a23-8f09-e413300e9f32___NREC_B.Spot_9085.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/5979f1be-c7a6-47c5-b438-60c3eab4218e___JR_B.Spot_9093.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/77d6d18a-0f6c-4417-80c6-42c0c9e7a83d___NREC_B.Spot_9147.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/e80de14e-9d15-4dc6-b519-6d5af14ba216___JR_B.Spot_8835.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/a3f4ee94-8c9f-4c38-8e64-b3928e6b3a95___JR_B.Spot_3204.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/3610f357-8b9f-4f98-8e7f-c4297daf3b20___NREC_B.Spot_1971.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/eeb59903-65af-4d9f-9ab9-ec6725aa3a39___JR_B.Spot_3359.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/fb3f399e-bc2f-418e-8b4e-a834b9f40c1b___JR_B.Spot_9097.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/29896da5-a228-4e67-8d23-930c40ebb03b___JR_B.Spot_8920.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/af404304-673d-4788-b622-104f2cb0e7be___JR_B.Spot_3257.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/4cf90b49-1b89-422e-84ae-2e2fcfc2fa02___JR_B.Spot_3362.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/b6d35d21-4812-4e32-ab9a-b6ddda8cbb79___JR_B.Spot_8972.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/37fbacb5-ed9d-48f2-bf19-37656ff7c317___JR_B.Spot_3307.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/d22776e6-5234-4c6b-a196-a04b281c3808___JR_B.Spot_3351.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/284b0fae-ce3c-43e7-acc6-e9a22bd6eb6f___JR_B.Spot_9074.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/d613de53-a4c4-49af-a909-29c4354c5ff2___NREC_B.Spot_9224.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/78cbd7cf-98fb-41f1-ae32-6655c02fa49c___JR_B.Spot_3292.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/33763f26-1135-458f-8b2b-34897b8bb647___JR_B.Spot_3323.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/8f9dedbd-e4c2-4bbb-b9c4-efb8d61bddc2___NREC_B.Spot_1882.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/17557939-f9e2-435a-a4e7-f4d3cff8aa8b___JR_B.Spot_3107.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/9184edd2-6056-4da1-aaeb-bc9dc92d5247___NREC_B.Spot_9155.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/7b3f4992-f771-4b6e-b25f-7ec4c5823c88___JR_B.Spot_8951.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/dab1cfaf-544d-48e0-bfe7-368d65761902___JR_B.Spot_8904.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/9be6504b-0be3-4169-80dd-139f579504a3___JR_B.Spot_8963.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/b36819f5-6791-44da-96ac-b89069921af6___JR_B.Spot_3130.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/080b107a-192f-40ce-8942-d8ccca8dfc52___NREC_B.Spot_1872.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/d9d20fce-3cef-4c89-8a3f-7294e05df853___JR_B.Spot_3225.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/41f3e9be-44a8-42b1-9654-8e7127bfc57e___JR_B.Spot_9048.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/1f838b54-c372-4b51-b398-6988377b2218___JR_B.Spot_8977.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/f176a365-b5f0-4b3f-a4bc-d4d2c705b29e___JR_B.Spot_3263.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/2433614e-78d3-45ae-b719-59efb0397572___JR_B.Spot_8966.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/99cd2ddf-fb89-41c3-91cc-0697293b3d9f___NREC_B.Spot_1948.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/41fed9b9-d409-4b56-a9d6-3e98f31a4e3a___JR_B.Spot_3275.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/447735c7-b650-4ef6-a53b-8fb661470de3___JR_B.Spot_3370.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/debfee6b-a167-480c-88dc-2b02279d7e93___JR_B.Spot_3158.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/a3736622-1bd1-4e57-8aa0-2b8ed898c2a4___NREC_B.Spot_9095.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/e5b0a108-d1ec-42ce-9953-e57cb218bb00___JR_B.Spot_3268.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/e26d8f48-59aa-4261-ba5a-a4461ebba8d2___JR_B.Spot_3222.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/389480c3-0209-45e3-b3ee-2447b22de68f___JR_B.Spot_9016.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/188f102a-6f64-4180-9d38-f98b61aaec60___JR_B.Spot_9014.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/37e9bf3a-85da-4114-8e69-185498b9a9af___JR_B.Spot_3337.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/8ebada57-3ce3-455d-ab53-c4a79d4f0b58___JR_B.Spot_3201.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/56a3748f-881d-4adb-ab0a-85b5cc6883a9___NREC_B.Spot_9180.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/a1e5160a-2a84-4b52-b765-4fbc507682a8___JR_B.Spot_3266.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/a82938f7-bbd4-4ccd-8482-f596735744a5___JR_B.Spot_3305.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/baaf70ae-a980-4cf0-a012-de1c2a35a2bd___JR_B.Spot_8822.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/b8eff1e7-9059-4c11-b931-fc1bc4ee0ae1___NREC_B.Spot_1972.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/ba9e7d81-876f-4c05-9578-ddd45d8b3526___JR_B.Spot_3330.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/b5d5a42e-5d4f-4429-8923-aee42e0a0c5d___NREC_B.Spot_9189.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/ef82ea58-8cfe-4e8f-a935-2b4e143618b1___JR_B.Spot_9079.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/032aa7c4-0a95-4f09-b0bb-1242f4f32d82___NREC_B.Spot_1889.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/6c859178-38ef-450e-8e93-c357957f5608___NREC_B.Spot_9061.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/c8ea8547-4f93-4bf9-af69-79f09697e817___JR_B.Spot_3152.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/bcf56f7d-d584-4fed-b42e-5cbf3b8707b7___JR_B.Spot_3197.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/5bdf4dcc-7f67-4dc6-92a3-671c6dd4c61f___JR_B.Spot_8942.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/e230f529-47b2-4841-9b10-2447be1b31da___NREC_B.Spot_9118.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/20a9aed4-ba56-413d-b88d-f4491cf184b3___JR_B.Spot_3265.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/0fe8a42b-b943-43d6-88c4-78abdcbfe02d___NREC_B.Spot_9236.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/f73b390b-591a-4f25-991d-3ff77a92a6f5___JR_B.Spot_3357.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/f2c48f6c-f92e-4543-816c-0621648003fe___JR_B.Spot_9010.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/d6b7a95f-019c-4cf6-b7da-d8bdc18a6c76___JR_B.Spot_9028.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/fc5d975d-8b5c-4e29-8490-34164c69cd3e___NREC_B.Spot_1832.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/8a9bc15a-fd14-44ac-b8eb-37ea8a209406___NREC_B.Spot_1819.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/875f41e8-cd70-44f4-a17c-c8b77fed406c___JR_B.Spot_8902.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/168a11c9-159b-468c-a6d9-07d0b61c42c9___JR_B.Spot_3193.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/e96d2d14-4400-4c28-894e-be7c071743f4___NREC_B.Spot_9175.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/8c9e49b1-c4ee-402e-b31b-a7b33e887d0c___JR_B.Spot_3313.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/bdb598d7-7b7a-45cb-921a-f37cf7105006___NREC_B.Spot_1908.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/e5781299-7fd6-4d80-aca1-d78910d9da1c___JR_B.Spot_3371.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/f3fb294f-21d3-44b3-bfab-256fed2fc2c8___NREC_B.Spot_9156.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/6cf6e676-20a1-45bc-8f5f-48445e5cbaa8___NREC_B.Spot_9086.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/6b1b260e-fab5-4a73-936c-5592119c13fe___NREC_B.Spot_1952.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/98558acc-09f4-4d2f-bdff-5e8e915ea606___NREC_B.Spot_9141.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/1a1af0c4-9e4a-4158-b982-f81d487a3b68___NREC_B.Spot_9148.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/db2c9432-9f29-4867-a07f-b6e78aa946a4___JR_B.Spot_3138.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/5e39aa56-cbda-4c20-9964-6a03c700cebd___NREC_B.Spot_1856.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/01940b6d-7dea-4889-a7b8-a35f4e9bba34___NREC_B.Spot_9120.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/bd2fcca9-6e34-44db-ade7-a0b595c97dcf___NREC_B.Spot_9126.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/82b9fdcc-3000-46fe-b955-063e77dd5968___JR_B.Spot_3324.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/2edf5fe8-706b-4ce7-8b59-dc6bfa4b6b42___JR_B.Spot_8823.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/9dbff8df-4ad1-46ec-96d7-4f35a27e2d5d___JR_B.Spot_8987.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/3700475e-b0b1-4b8b-90bd-374be22dbfd0___NREC_B.Spot_1860.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/ba89789a-d506-48d5-964b-41f5815d46b1___JR_B.Spot_3352.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/42268507-28e9-4fb2-bd74-a2afdb3eebfa___JR_B.Spot_3240.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/a32c2976-7ef3-4dfa-95d8-c3c056b36012___JR_B.Spot_3145.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/2414f9df-91fd-4aed-b772-bd6b5311eb0b___JR_B.Spot_3141.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/bd493982-5fe3-4851-b4d3-1e9e962f1d70___NREC_B.Spot_1876.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/3a56f122-0d06-45c2-bc2b-0636d42a7545___JR_B.Spot_9088.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/73ef1d83-6ac0-4955-938a-fca94432814b___JR_B.Spot_3148.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/4cda1135-6cad-421b-9648-d00f9f3cd16f___JR_B.Spot_3304.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/0915c9a9-25b0-4728-be01-86e5cecb57df___NREC_B.Spot_1816.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/884c2da1-3b43-46aa-85bb-0f72ed25c266___JR_B.Spot_8906.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/0d8421cd-eebc-4018-b591-12352dd970a7___JR_B.Spot_3234.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/72572ac8-d26b-4684-8e8c-7b396677f2fc___NREC_B.Spot_9191.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/d3522fcb-a325-48b2-8b37-881a56e190e4___NREC_B.Spot_9047.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/f73f0a24-d25e-4a0c-9e68-3b57d467090d___JR_B.Spot_8829.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/aa74582c-f87a-46cb-9be9-83fcb11a94b6___JR_B.Spot_3315.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/43fb5703-5a76-47cf-b027-42a9bd601401___JR_B.Spot_9033.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/58797902-c466-4226-b913-dcd09c9e026f___NREC_B.Spot_1844.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/8695a15f-cdb4-444f-817b-7f4fc22a7a7a___NREC_B.Spot_9230.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/0c99cb45-b4e0-4ade-bba5-fab3b678f0bb___JR_B.Spot_8912.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/94b1fbe4-4a9d-4237-a6ca-41a6db87d654___JR_B.Spot_3242.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/4bad40b0-af40-4deb-820c-edbcbb9ea372___NREC_B.Spot_1843.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/c5ae280d-bbc4-4ef5-8c09-38a241b8c00d___NREC_B.Spot_9199.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/28f23e77-e556-40c8-8bc2-835227732de2___JR_B.Spot_8848.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/2b562d10-5ccf-4f20-aadc-2e1480bd303e___JR_B.Spot_3256.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/6e789f9f-96b0-4221-9755-a75ca579def7___NREC_B.Spot_1795.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/d890ffc6-e6c8-4ef6-bde4-980cf0a465e1___JR_B.Spot_8945.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/a88f92fc-0522-4568-a9d7-850eb67c2602___NREC_B.Spot_9109.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/fa1c19f6-4e9e-4452-ad0d-99f65d5c9909___NREC_B.Spot_1960.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/b1c60a36-0aa1-4051-8dfe-db3ab7feeb39___JR_B.Spot_3406.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/5220d08b-9ead-4c12-9a25-7044d1669d0d___JR_B.Spot_3208.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/532c9cb3-3018-4217-b59c-c16b8473423d___JR_B.Spot_3339.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/8efc7a6c-216f-4c32-99a1-43335c3385a8___JR_B.Spot_3213.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/c6fce723-0700-4184-9444-b570dd4263f5___NREC_B.Spot_1837.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/51185964-48e2-493e-a052-42139dd0facd___JR_B.Spot_3331.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/6e1e07ba-212d-4494-b8bf-73d12d720c20___JR_B.Spot_3392.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/c8080916-dd9d-40c4-a39b-1957ebd17b87___NREC_B.Spot_9115.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/1732db7e-9901-46df-b20e-3ca49ff1dbad___NREC_B.Spot_1791.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/3233e1db-99e9-4107-8711-c8b28a8bfda1___JR_B.Spot_3165.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/a3407dfc-9a97-4dd4-b484-527da44a161c___JR_B.Spot_9029.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/b0d97a12-ed6a-41f0-9772-bb3b801e6041___NREC_B.Spot_9194.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/f0f2b399-c9fe-462a-961c-2cfc9e5318b9___NREC_B.Spot_9101.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/8e049c5d-6a3b-4972-94e3-057e6cbe3892___NREC_B.Spot_1901.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/2b710a19-f4cd-4bcf-afbf-e48face96045___NREC_B.Spot_1931.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/2bb75692-d488-406d-bce0-c7eab42557c5___NREC_B.Spot_1922.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/01dfb88b-cd5a-420c-b163-51f5fe07b74d___JR_B.Spot_9091.jpg
# /kaggle/input/mission1111/Mission/test/Pepper__bell___Bacterial_spot/1092e87d-5d66-43cd-8344-43b393d86065___NREC_B.Spot_9244.jpg
# /kaggle/input/mission1111/Mission/test/Potato___healthy/8665efd2-fa3d-45f8-b1c0-746c99fb7d1e___RS_HL_1924.jpg
# /kaggle/input/mission1111/Mission/test/Potato___healthy/fd92bd9c-02cb-4599-8673-9316159504a1___RS_HL_1927.jpg
# /kaggle/input/mission1111/Mission/test/Potato___healthy/a8d687be-3777-403f-bae7-5c8c19340b3f___RS_HL_1738.jpg
# /kaggle/input/mission1111/Mission/test/Potato___healthy/750584fd-72e0-45c8-b37c-97208bd559cc___RS_HL_1885.jpg
# /kaggle/input/mission1111/Mission/test/Potato___healthy/949cafd0-098b-497f-9590-f0fb8ccafc94___RS_HL_4168.jpg
# /kaggle/input/mission1111/Mission/test/Potato___healthy/774875d3-438a-4305-afe2-7d59e2925dc4___RS_HL_1759.jpg
# /kaggle/input/mission1111/Mission/test/Potato___healthy/a5050bde-febc-4931-b31d-45c9652df318___RS_HL_5373.jpg
# /kaggle/input/mission1111/Mission/test/Potato___healthy/d340704d-cc00-4068-bb8a-ae70840b7bfa___RS_HL_1773.jpg
# /kaggle/input/mission1111/Mission/test/Potato___healthy/d287be3d-cac6-4485-8c31-674fb8b459be___RS_HL_1973.jpg
# /kaggle/input/mission1111/Mission/test/Potato___healthy/a1abff90-34e5-464d-b4d3-0c09f5924900___RS_HL_5414.jpg
# /kaggle/input/mission1111/Mission/test/Potato___healthy/e693354a-053c-4093-8642-cc8f5f9eb2cc___RS_HL_1746.jpg
# /kaggle/input/mission1111/Mission/test/Potato___healthy/c6204cb3-cd9f-4d7b-92a6-9773fe562cab___RS_HL_1939.jpg
# /kaggle/input/mission1111/Mission/test/Potato___healthy/b42621c3-f751-46e1-a8d2-83ed85b90554___RS_HL_1740.jpg
# /kaggle/input/mission1111/Mission/test/Potato___healthy/c85bacb0-e5e8-4127-a0b0-a7342f2cab5f___RS_HL_5406.jpg
# /kaggle/input/mission1111/Mission/test/Potato___healthy/b28c43f9-5844-4e9b-86bf-36bc114cae07___RS_HL_1736.jpg
# /kaggle/input/mission1111/Mission/test/Potato___healthy/8c1e1281-5937-4559-a02f-02817de6e122___RS_HL_4173.jpg
# /kaggle/input/mission1111/Mission/test/Potato___healthy/00fc2ee5-729f-4757-8aeb-65c3355874f2___RS_HL_1864.jpg
# /kaggle/input/mission1111/Mission/test/Potato___healthy/415ac4a2-8f16-4052-880e-1e1f208965f0___RS_HL_1884.jpg
# /kaggle/input/mission1111/Mission/test/Potato___healthy/3a00204c-5e53-4e5d-95a6-f8819031744e___RS_HL_5420.jpg
# /kaggle/input/mission1111/Mission/test/Potato___healthy/f66af6c0-6fc6-4020-b1de-a73685d497c2___RS_HL_4181.jpg
# /kaggle/input/mission1111/Mission/test/Potato___healthy/1ae826e2-5148-47bd-a44c-711ec9cc9c75___RS_HL_1954.jpg
# /kaggle/input/mission1111/Mission/test/Potato___healthy/57c2663b-5d1d-4476-b067-38b2149c3b2d___RS_HL_1796.jpg
# /kaggle/input/mission1111/Mission/test/Potato___healthy/762672f4-17e6-4fd6-84f1-3bcb091b3ca5___RS_HL_5417.jpg
# /kaggle/input/mission1111/Mission/test/Potato___healthy/9c620128-2872-4bbb-bc14-d5b785242cf6___RS_HL_1751.jpg
# /kaggle/input/mission1111/Mission/test/Potato___healthy/0be9d721-82f5-42c3-b535-7494afe01dbe___RS_HL_1814.jpg
# /kaggle/input/mission1111/Mission/test/Potato___healthy/bb328d40-e4e6-4b84-a92a-e7cb3922c19d___RS_HL_1829.jpg
# /kaggle/input/mission1111/Mission/test/Potato___healthy/f30983c0-6e20-43cc-8672-4622ca34c830___RS_HL_1949.jpg
# /kaggle/input/mission1111/Mission/test/Potato___healthy/ee052892-e935-4fbb-9344-4d23c57c6890___RS_HL_5400.jpg
# /kaggle/input/mission1111/Mission/test/Potato___healthy/c6abf1da-b06f-4cd2-8af6-d68be5eff6f9___RS_HL_1766.jpg
# /kaggle/input/mission1111/Mission/test/Potato___healthy/f4be3632-42a1-415a-9f7e-1d5ecb9f49d7___RS_HL_1783.jpg
# /kaggle/input/mission1111/Mission/test/Potato___healthy/57e24d88-fd01-4422-b8b5-d688d2296184___RS_HL_5401.jpg
# /kaggle/input/mission1111/Mission/test/Potato___healthy/8583c4ff-2d8b-4b6f-89a8-fcc98917ce9b___RS_HL_1961.jpg
# /kaggle/input/mission1111/Mission/test/Potato___healthy/683b04ad-7941-4819-9965-ba32c725eb22___RS_HL_1861.jpg
# /kaggle/input/mission1111/Mission/test/Potato___healthy/5e19b1f4-fd65-4c4d-bcd2-18c8c519eddb___RS_HL_1965.jpg
# /kaggle/input/mission1111/Mission/test/Potato___healthy/a02b6205-b40a-4178-8b34-3494f84b9d1f___RS_HL_1958.jpg
# /kaggle/input/mission1111/Mission/test/Potato___healthy/ad9b6cf4-e065-496d-91c7-5713ce14e19e___RS_HL_1926.jpg
# /kaggle/input/mission1111/Mission/test/Potato___healthy/5ea316eb-10a2-42c0-b781-40d90356ccaa___RS_HL_1935.jpg
# /kaggle/input/mission1111/Mission/test/Potato___healthy/71c06efe-089f-49b3-beed-095bd7640e32___RS_HL_1947.jpg
# /kaggle/input/mission1111/Mission/test/Potato___healthy/bb04f738-1848-4dda-8834-384a48b335cd___RS_HL_1765.jpg
# /kaggle/input/mission1111/Mission/test/Potato___healthy/23f4d3b1-23f4-43fb-96c2-dae37224ec74___RS_HL_1803.jpg
# /kaggle/input/mission1111/Mission/test/Potato___healthy/b0fe9fe9-52e7-40e4-b4c0-769f1a0c7fb9___RS_HL_4175.jpg
# /kaggle/input/mission1111/Mission/test/Potato___healthy/1f9870b3-899e-46fb-98c9-cfc2ce92895b___RS_HL_1816.jpg
# /kaggle/input/mission1111/Mission/test/Potato___healthy/3c0d6888-c7e1-4cf8-9c25-9a0b8c62ba72___RS_HL_1780.jpg
# /kaggle/input/mission1111/Mission/test/Potato___healthy/b9ea902d-e557-4fa5-893b-39a7a57c0121___RS_HL_1893.jpg
# /kaggle/input/mission1111/Mission/test/Potato___healthy/2e0b8b4b-e900-408b-b760-730690bbd382___RS_HL_1901.jpg
# /kaggle/input/mission1111/Mission/test/Potato___healthy/45bc0b37-ca59-4a89-8531-705af42a6fd5___RS_HL_1946.jpg
# /kaggle/input/mission1111/Mission/test/Tomato_Leaf_Mold/905a051a-0649-4b4a-8dc7-273952cbd832___Crnl_L.Mold_6574.jpg
# /kaggle/input/mission1111/Mission/test/Tomato_Leaf_Mold/bb3b17dd-b745-4706-8e03-ff2660d77c23___Crnl_L.Mold_6512.jpg
# /kaggle/input/mission1111/Mission/test/Tomato_Leaf_Mold/f3b8f9e3-6c47-4797-9da6-d8b09e19048c___Crnl_L.Mold_9023.jpg
# /kaggle/input/mission1111/Mission/test/Tomato_Leaf_Mold/3a7f507d-76d7-4489-baf4-2e4dad468173___Crnl_L.Mold_8784.jpg
# /kaggle/input/mission1111/Mission/test/Tomato_Leaf_Mold/81de0497-5011-4330-b2f1-b12c7b83576f___Crnl_L.Mold_7120.jpg
# /kaggle/input/mission1111/Mission/test/Tomato_Leaf_Mold/705e1448-cb1b-4047-802a-a0deb547bc2e___Crnl_L.Mold_8670.jpg
# /kaggle/input/mission1111/Mission/test/Tomato_Leaf_Mold/097b050a-eaa4-4e4a-a30a-b72d1a4c0cc4___Crnl_L.Mold_8682.jpg
# /kaggle/input/mission1111/Mission/test/Tomato_Leaf_Mold/b0636c15-fdf5-4835-a5f9-57875579f53b___Crnl_L.Mold_6668.jpg
# /kaggle/input/mission1111/Mission/test/Tomato_Leaf_Mold/b2ba5e8d-5cbd-472c-b736-84949fa2b8ad___Crnl_L.Mold_6744.jpg
# /kaggle/input/mission1111/Mission/test/Tomato_Leaf_Mold/f48a7999-9eaa-4403-a2a5-533d22092d46___Crnl_L.Mold_6854.jpg
# /kaggle/input/mission1111/Mission/test/Tomato_Leaf_Mold/b7b40130-ae85-438e-9bc4-7ed4ce5cdd1f___Crnl_L.Mold_9137.jpg
# /kaggle/input/mission1111/Mission/test/Tomato_Leaf_Mold/8130385a-3f81-4fd6-9966-6f392cf90329___Crnl_L.Mold_8753.jpg
# /kaggle/input/mission1111/Mission/test/Tomato_Leaf_Mold/19014458-f5de-4c92-beb5-8faf0e6a6bf3___Crnl_L.Mold_8754.jpg
# /kaggle/input/mission1111/Mission/test/Tomato_Leaf_Mold/354c1fb7-f8ee-4a39-af91-0e5ef49b20bb___Crnl_L.Mold_8959.jpg
# /kaggle/input/mission1111/Mission/test/Tomato_Leaf_Mold/2b8557bc-3b98-4169-826c-628c5a683d70___Crnl_L.Mold_6539.jpg
# /kaggle/input/mission1111/Mission/test/Tomato_Leaf_Mold/2857df1b-3a91-46d2-ab63-926b329b4a28___Crnl_L.Mold_7102.jpg
# /kaggle/input/mission1111/Mission/test/Tomato_Leaf_Mold/aeec2942-315c-4297-90a2-4dc24f491a5c___Crnl_L.Mold_6925.jpg
# /kaggle/input/mission1111/Mission/test/Tomato_Leaf_Mold/0a555f63-bf03-4958-8993-e1932b8dce9f___Crnl_L.Mold_9064.jpg
# /kaggle/input/mission1111/Mission/test/Tomato_Leaf_Mold/a47a2d12-bac3-43c8-88d3-0f35e6884381___Crnl_L.Mold_8688.jpg
# /kaggle/input/mission1111/Mission/test/Tomato_Leaf_Mold/452bc068-6862-4715-a724-a4057d4155ee___Crnl_L.Mold_6866.jpg
# /kaggle/input/mission1111/Mission/test/Tomato_Leaf_Mold/41b84dbf-0402-4480-a0b2-55ab4686dcdf___Crnl_L.Mold_8933.jpg
# /kaggle/input/mission1111/Mission/test/Tomato_Leaf_Mold/036d12b0-1e97-4975-bd80-a8a3c48588e7___Crnl_L.Mold_6500.jpg
# /kaggle/input/mission1111/Mission/test/Tomato_Leaf_Mold/c3d8cc45-95c1-4747-b449-9a44ca4e9704___Crnl_L.Mold_8730.jpg
# /kaggle/input/mission1111/Mission/test/Tomato_Leaf_Mold/f85b350c-a7cf-4652-87e7-5e039e82021d___Crnl_L.Mold_8927.jpg
# /kaggle/input/mission1111/Mission/test/Tomato_Leaf_Mold/bcab5afc-96ce-4b88-8801-8e905b783ef3___Crnl_L.Mold_9094.jpg
# /kaggle/input/mission1111/Mission/test/Tomato_Leaf_Mold/538d20ab-b01e-4d55-ad39-b0fbeb3babbe___Crnl_L.Mold_7002.jpg
# /kaggle/input/mission1111/Mission/test/Tomato_Leaf_Mold/20bfb40a-3fac-43d0-8864-feb28b97b9cd___Crnl_L.Mold_6849.jpg
# /kaggle/input/mission1111/Mission/test/Tomato_Leaf_Mold/bf120193-9127-4e56-8031-9b0cded8a75d___Crnl_L.Mold_9004.jpg
# /kaggle/input/mission1111/Mission/test/Tomato_Leaf_Mold/df78e8cb-8fc5-4682-ab5c-f265b4e8d97e___Crnl_L.Mold_8619.jpg
# /kaggle/input/mission1111/Mission/test/Tomato_Leaf_Mold/ea19d516-b7fd-45c3-a459-68281f3bd9aa___Crnl_L.Mold_6836.jpg
# /kaggle/input/mission1111/Mission/test/Tomato_Leaf_Mold/3d203bd1-7814-4d66-a2eb-cf97193c1fbb___Crnl_L.Mold_8960.jpg
# /kaggle/input/mission1111/Mission/test/Tomato_Leaf_Mold/32e7769c-b63c-413a-a623-deebcdb2ec82___Crnl_L.Mold_8757.jpg
# /kaggle/input/mission1111/Mission/test/Tomato_Leaf_Mold/8b30edb3-09a7-4419-a06a-9dddb5194a38___Crnl_L.Mold_8847.jpg
# /kaggle/input/mission1111/Mission/test/Tomato_Leaf_Mold/f0e71c5c-4a0b-4b97-88db-19438a52d9b1___Crnl_L.Mold_8751.jpg
# /kaggle/input/mission1111/Mission/test/Tomato_Leaf_Mold/5fc8babb-214b-459a-9440-898cedeb4944___Crnl_L.Mold_8667.jpg
# /kaggle/input/mission1111/Mission/test/Tomato_Leaf_Mold/8f4781c0-53fa-4056-839e-400915d8aa5e___Crnl_L.Mold_6683.jpg
# /kaggle/input/mission1111/Mission/test/Tomato_Leaf_Mold/329f2f31-ceca-402f-a007-21d64fe75f5e___Crnl_L.Mold_6519.jpg
# /kaggle/input/mission1111/Mission/test/Tomato_Leaf_Mold/19fc6cfd-7430-4695-a4e1-5c947193ab46___Crnl_L.Mold_6922.jpg
# /kaggle/input/mission1111/Mission/test/Tomato_Leaf_Mold/0adab1d4-5696-4cd8-8453-3931b70e856d___Crnl_L.Mold_8689.jpg
# ...
# /kaggle/input/mission1111/Mission/train/Tomato__Tomato_mosaic_virus/e03cb55d-6525-4186-a318-5c06c0691642___PSU_CG_2353.jpg
# /kaggle/input/mission1111/Mission/train/Tomato__Tomato_mosaic_virus/b5987570-3fbe-4a4c-9790-1d55bcfd2c61___PSU_CG_2288.jpg
# /kaggle/input/mission1111/Mission/train/Tomato__Tomato_mosaic_virus/dcb74f2b-c523-4147-b9ce-690800411273___PSU_CG_2154.jpg
# /kaggle/input/mission1111/Mission/train/Tomato__Tomato_mosaic_virus/b2cb36e6-ff72-4518-b344-a6500af4fa40___PSU_CG_2332.jpg
# /kaggle/input/mission1111/Mission/train/Tomato__Tomato_mosaic_virus/a4453e9a-4ede-4377-be38-fd77e9bf16f0___PSU_CG_2308.jpg
# /kaggle/input/mission1111/Mission/train/Tomato__Tomato_mosaic_virus/0c676b36-7985-42e8-b550-83e2b1c55535___PSU_CG_2177.jpg
# /kaggle/input/mission1111/Mission/train/Tomato__Tomato_mosaic_virus/47135ee0-8924-4fa2-b9ef-122d0d3eb629___PSU_CG_2194.jpg
# /kaggle/input/mission1111/Mission/train/Tomato__Tomato_mosaic_virus/7d35f41d-27d1-4ff8-8527-54ca210a47b5___PSU_CG_2359.jpg
# /kaggle/input/mission1111/Mission/train/Tomato__Tomato_mosaic_virus/597f8dc8-681f-49a8-8985-4ba5b181b53a___PSU_CG_2193.jpg
# /kaggle/input/mission1111/Mission/train/Tomato__Tomato_mosaic_virus/a72414b0-f520-4044-abeb-cd09c28b4a9f___PSU_CG_2267.jpg
# /kaggle/input/mission1111/Mission/train/Tomato__Tomato_mosaic_virus/d53047af-8624-4c80-a2be-8aa9ea6f0a35___PSU_CG_2208.jpg
# /kaggle/input/mission1111/Mission/train/Tomato__Tomato_mosaic_virus/76d665fa-6aec-4c47-adac-069107b3cf46___PSU_CG_2268.jpg
# /kaggle/input/mission1111/Mission/train/Tomato__Tomato_mosaic_virus/9563b3bb-b942-4d32-9582-0b4021aaf116___PSU_CG_2229.jpg
# /kaggle/input/mission1111/Mission/train/Tomato__Tomato_mosaic_virus/ccbfedd0-e8d7-4f09-aa7b-98213e408c39___PSU_CG_2216.jpg
# /kaggle/input/mission1111/Mission/train/Tomato__Tomato_mosaic_virus/f7066d3e-694d-44a0-a42a-a8fb1eb52ff7___PSU_CG_2190.jpg
# /kaggle/input/mission1111/Mission/train/Tomato__Tomato_mosaic_virus/274c03c3-c69a-4182-ba3f-d6e93b2dea0b___PSU_CG_2349.jpg
# /kaggle/input/mission1111/Mission/train/Tomato__Tomato_mosaic_virus/658e96ee-271d-442b-876e-a52970ff540f___PSU_CG_2269.jpg
# /kaggle/input/mission1111/Mission/train/Tomato__Tomato_mosaic_virus/65226438-efaa-4bf4-91e7-e459e3528565___PSU_CG_2143.jpg
# /kaggle/input/mission1111/Mission/train/Tomato__Tomato_mosaic_virus/58ddf6d1-0e20-4c35-944f-d50c922a07d8___PSU_CG_2415.jpg
# /kaggle/input/mission1111/Mission/train/Tomato__Tomato_mosaic_virus/67662638-1bfa-4ff6-8305-2d8544277ef0___PSU_CG_2222.jpg
# /kaggle/input/mission1111/Mission/train/Tomato__Tomato_mosaic_virus/f3d26b9f-7999-4b20-8503-0e1d3a878742___PSU_CG_2304.jpg
# /kaggle/input/mission1111/Mission/train/Tomato__Tomato_mosaic_virus/67c65196-795d-4df0-bbd8-0c18af1028c1___PSU_CG_2387.jpg
# /kaggle/input/mission1111/Mission/train/Tomato__Tomato_mosaic_virus/43f4bccf-0e70-479a-9880-5523f8ffbe9b___PSU_CG_2367.jpg
# /kaggle/input/mission1111/Mission/train/Tomato__Tomato_mosaic_virus/f600fd06-c834-4305-83b2-ee1bd08cea49___PSU_CG_2235.jpg
# /kaggle/input/mission1111/Mission/train/Tomato__Tomato_mosaic_virus/8b43c3f3-73ae-47bc-a620-079ebeeb10a4___PSU_CG_2094.jpg
# /kaggle/input/mission1111/Mission/train/Tomato__Tomato_mosaic_virus/a409fdf6-263d-4160-b007-52e531010def___PSU_CG_2291.jpg
# /kaggle/input/mission1111/Mission/train/Tomato__Tomato_mosaic_virus/7569fab7-ac19-4ac4-a01b-b77a4abb0c29___PSU_CG_2350.jpg
# /kaggle/input/mission1111/Mission/train/Tomato__Tomato_mosaic_virus/629e19d4-c6f5-457f-9e17-80a1e77140fe___PSU_CG_2129.jpg
# /kaggle/input/mission1111/Mission/train/Tomato__Tomato_mosaic_virus/21fe0741-4ff6-4f8f-8969-6b8bdeea58fa___PSU_CG_2278.jpg
# /kaggle/input/mission1111/Mission/train/Tomato__Tomato_mosaic_virus/0bf3eb4c-e2cd-4e72-8834-4fc045bd67ae___PSU_CG_2414.jpg
# /kaggle/input/mission1111/Mission/train/Tomato__Tomato_mosaic_virus/15f1e22a-9c70-4060-a275-fac10c196341___PSU_CG_2118.jpg
# /kaggle/input/mission1111/Mission/train/Tomato__Tomato_mosaic_virus/3f2e59c8-d048-4995-adc0-a9a758044b8d___PSU_CG_2206.jpg
# /kaggle/input/mission1111/Mission/train/Tomato__Tomato_mosaic_virus/169a7634-85a7-4096-85a3-4e75de98defe___PSU_CG_2226.jpg
# /kaggle/input/mission1111/Mission/train/Tomato__Tomato_mosaic_virus/dcbf5ac4-f25b-4e62-999b-44e1892db4ab___PSU_CG_2107.jpg
# /kaggle/input/mission1111/Mission/train/Tomato__Tomato_mosaic_virus/b801ed5c-9127-4ce5-b71f-5480620510cf___PSU_CG_2252.jpg
# /kaggle/input/mission1111/Mission/train/Tomato__Tomato_mosaic_virus/6804695f-56f8-4ff9-90f8-69ee95097463___PSU_CG_2067.jpg
# /kaggle/input/mission1111/Mission/train/Tomato__Tomato_mosaic_virus/91247151-4bae-4d55-a35c-edb9318bdb09___PSU_CG_2139.jpg
# /kaggle/input/mission1111/Mission/train/Tomato__Tomato_mosaic_virus/27000177-5a1d-4539-b78d-07a6f9a38089___PSU_CG_2168.jpg
# /kaggle/input/mission1111/Mission/train/Tomato__Tomato_mosaic_virus/54355f0e-7332-4990-b96e-fbff2637f5b7___PSU_CG_2245.jpg
# /kaggle/input/mission1111/Mission/train/Tomato__Tomato_mosaic_virus/b3937c46-37f8-4216-b0cc-db591b1c3514___PSU_CG_2186.jpg
# /kaggle/input/mission1111/Mission/train/Tomato__Tomato_mosaic_virus/73be89b4-f57a-4230-a0e4-4a0f50230fc7___PSU_CG_2142.jpg
# /kaggle/input/mission1111/Mission/train/Tomato__Tomato_mosaic_virus/b23eb7f0-daa4-4775-a09c-f87363bdc141___PSU_CG_2255.jpg
# /kaggle/input/mission1111/Mission/train/Tomato__Tomato_mosaic_virus/c1ca36c4-bffc-494d-9199-0753d7319bce___PSU_CG_2357.jpg
# /kaggle/input/mission1111/Mission/train/Tomato__Tomato_mosaic_virus/2f240e5e-cbb9-406a-98aa-12028411429c___PSU_CG_2123.jpg
# /kaggle/input/mission1111/Mission/train/Tomato__Tomato_mosaic_virus/5f45109b-365d-47f2-9921-07e576ac9a93___PSU_CG_2314.jpg
# /kaggle/input/mission1111/Mission/train/Tomato__Tomato_mosaic_virus/02cb8c4e-4542-4020-bb46-025de54d97ae___PSU_CG_2098.jpg
# /kaggle/input/mission1111/Mission/train/Tomato__Tomato_mosaic_virus/efd2cbd0-24dc-4c09-92b1-37963ae84721___PSU_CG_2379.jpg
# /kaggle/input/mission1111/Mission/train/Tomato__Tomato_mosaic_virus/86965ac5-b790-4218-a3c6-216d10da5211___PSU_CG_2066.jpg
# /kaggle/input/mission1111/Mission/train/Tomato__Tomato_mosaic_virus/453cf1e5-cfb7-4350-8257-c51a47fb36b8___PSU_CG_2111.jpg
# /kaggle/input/mission1111/Mission/train/Tomato__Tomato_mosaic_virus/1b9dc07a-40ab-45bc-a873-1ad4212e35a3___PSU_CG_2289.jpg
# /kaggle/input/mission1111/Mission/train/Tomato__Tomato_mosaic_virus/f85cef40-132b-4be8-8781-d8e5c14c7f22___PSU_CG_2242.jpg
# /kaggle/input/mission1111/Mission/train/Tomato__Tomato_mosaic_virus/b2622141-87e3-4d73-8eb0-21401f3bbab5___PSU_CG_2144.jpg
# /kaggle/input/mission1111/Mission/train/Tomato__Tomato_mosaic_virus/6e36029a-1c73-49e6-80b9-5e5cf12f43c1___PSU_CG_2217.jpg
# /kaggle/input/mission1111/Mission/train/Tomato__Tomato_mosaic_virus/fb199918-5c7f-4285-993b-3ed212140456___PSU_CG_2124.jpg
# /kaggle/input/mission1111/Mission/train/Tomato__Tomato_mosaic_virus/79f7f0e7-f4c8-4cf4-9c5d-2c4c4675fc04___PSU_CG_2147.jpg
# /kaggle/input/mission1111/Mission/train/Tomato__Tomato_mosaic_virus/01b32f27-2b9b-4961-805b-8066bf4d90f1___PSU_CG_2417.jpg
# /kaggle/input/mission1111/Mission/train/Tomato__Tomato_mosaic_virus/c1ff629a-8390-43a4-88ed-86e462d688a7___PSU_CG_2083.jpg
# /kaggle/input/mission1111/Mission/train/Tomato__Tomato_mosaic_virus/382828a4-dbdf-4ddc-a75b-9a6fcc4b600e___PSU_CG_2054.jpg
# /kaggle/input/mission1111/Mission/train/Tomato__Tomato_mosaic_virus/bf950cb4-985f-4174-b32b-9ae2d6e99a84___PSU_CG_2320.jpg
# /kaggle/input/mission1111/Mission/train/Tomato__Tomato_mosaic_virus/dd1161b0-ed4e-42f0-a63b-1ff8d9adf3ed___PSU_CG_2405.jpg
# /kaggle/input/mission1111/Mission/train/Tomato__Tomato_mosaic_virus/a5bc7391-adbd-4d94-89b0-e3aeb7ba81b9___PSU_CG_2368.jpg
# /kaggle/input/mission1111/Mission/train/Tomato__Tomato_mosaic_virus/b9c75527-d6ee-4c24-b293-9618b378157c___PSU_CG_2130.jpg
# /kaggle/input/mission1111/Mission/train/Tomato__Tomato_mosaic_virus/16f91dc7-59a2-4cc3-b896-64e28bc60ced___PSU_CG_2108.jpg
# /kaggle/input/mission1111/Mission/train/Tomato__Tomato_mosaic_virus/afd8bd61-a7fe-4ee1-8cf8-afa0c116d751___PSU_CG_2391.jpg
# /kaggle/input/mission1111/Mission/train/Tomato__Tomato_mosaic_virus/4571a1c4-3a67-4437-a5bf-8bc1a2af22e4___PSU_CG_2360.jpg
# /kaggle/input/mission1111/Mission/train/Tomato__Tomato_mosaic_virus/59f9754c-2d49-4a74-ba11-4f9a017c8348___PSU_CG_2200.jpg
# /kaggle/input/mission1111/Mission/train/Tomato__Tomato_mosaic_virus/0fefaaee-79e4-45a6-8606-5a4ab1ea43a2___PSU_CG_2398.jpg
# /kaggle/input/mission1111/Mission/train/Tomato__Tomato_mosaic_virus/0f47e5f6-7271-45c8-8364-e962dedd83c9___PSU_CG_2148.jpg
# /kaggle/input/mission1111/Mission/train/Tomato__Tomato_mosaic_virus/570486a0-abe0-4046-add9-14aab37de620___PSU_CG_2313.jpg
# /kaggle/input/mission1111/Mission/train/Tomato__Tomato_mosaic_virus/82a23930-4324-4d3e-b599-9861796f01db___PSU_CG_2366.jpg
# /kaggle/input/mission1111/Mission/train/Tomato__Tomato_mosaic_virus/0a7cc59f-b2b0-4201-9c4a-d91eca5c03a3___PSU_CG_2230.jpg
# /kaggle/input/mission1111/Mission/train/Tomato__Tomato_mosaic_virus/46b3cb66-9265-464f-9b0a-ac23eb72a4a0___PSU_CG_2411.jpg
# /kaggle/input/mission1111/Mission/train/Tomato__Tomato_mosaic_virus/66778ba1-eb89-4597-913a-71c68eb0251e___PSU_CG_2274.jpg
# /kaggle/input/mission1111/Mission/train/Tomato__Tomato_mosaic_virus/89bc4fcf-1c6c-4285-84b5-564fd657e150___PSU_CG_2419.jpg
# /kaggle/input/mission1111/Mission/train/Tomato__Tomato_mosaic_virus/da2bbe3c-5626-46d2-9640-2da89552f113___PSU_CG_2319.jpg
# /kaggle/input/mission1111/Mission/train/Tomato__Tomato_mosaic_virus/4ab5b752-6622-42f2-8743-fa9c9b03e137___PSU_CG_2120.jpg
# /kaggle/input/mission1111/Mission/train/Tomato__Tomato_mosaic_virus/faaab5c4-517e-4417-b471-fa1d762e35c4___PSU_CG_2173.jpg
# /kaggle/input/mission1111/Mission/train/Tomato__Tomato_mosaic_virus/6b15d0fc-1089-4f54-955a-0d1ebbf0ab30___PSU_CG_2364.jpg
# /kaggle/input/mission1111/Mission/train/Tomato__Tomato_mosaic_virus/9a3941e6-32bc-4417-862b-2f03e4040b65___PSU_CG_2159.jpg
# /kaggle/input/mission1111/Mission/train/Tomato__Tomato_mosaic_virus/6e8fac68-5902-4a78-a5c1-05c1c9dd006f___PSU_CG_2343.jpg
# /kaggle/input/mission1111/Mission/train/Tomato__Tomato_mosaic_virus/8af472ce-108f-4478-807f-cdf8f4cbdceb___PSU_CG_2218.jpg
# /kaggle/input/mission1111/Mission/train/Tomato__Tomato_mosaic_virus/a3f05d12-0e65-4f04-8f7d-5299124eb392___PSU_CG_2204.jpg
# /kaggle/input/mission1111/Mission/train/Tomato__Tomato_mosaic_virus/b32647fc-d502-4bb4-99f6-3003874daee4___PSU_CG_2246.jpg
# /kaggle/input/mission1111/Mission/train/Tomato__Tomato_mosaic_virus/b455e70e-1ff9-4081-a0bb-6d16c88402e3___PSU_CG_2105.jpg
# /kaggle/input/mission1111/Mission/train/Tomato__Tomato_mosaic_virus/99e849b4-3c38-4a96-ba96-14a133861e06___PSU_CG_2151.jpg
# /kaggle/input/mission1111/Mission/train/Tomato__Tomato_mosaic_virus/3a99961c-cc66-44a9-b2c7-4d5a0714e839___PSU_CG_2162.jpg
# /kaggle/input/mission1111/Mission/train/Tomato__Tomato_mosaic_virus/eeeb214a-2f7d-4e91-991f-003a3a9508be___PSU_CG_2078.jpg
# /kaggle/input/mission1111/Mission/train/Tomato__Tomato_mosaic_virus/ecc79dcf-6446-4df2-a8c8-ab322effeec3___PSU_CG_2220.jpg
# /kaggle/input/mission1111/Mission/train/Tomato__Tomato_mosaic_virus/9ec78399-de3a-4431-a5fc-e100406c5642___PSU_CG_2275.jpg
# /kaggle/input/mission1111/Mission/train/Tomato__Tomato_mosaic_virus/cc8059de-bae3-4ace-b6a5-f12a07fef342___PSU_CG_2410.jpg
# /kaggle/input/mission1111/Mission/train/Tomato__Tomato_mosaic_virus/fb79c897-ed92-43c4-8b28-8bdbe951ff56___PSU_CG_2396.jpg
# /kaggle/input/mission1111/Mission/train/Tomato__Tomato_mosaic_virus/bd533964-8188-49ba-92e8-334cdc4ecb70___PSU_CG_2369.jpg
# /kaggle/input/mission1111/Mission/train/Tomato__Tomato_mosaic_virus/119554ae-c777-46da-abb7-591404fdc65f___PSU_CG_2393.jpg
# /kaggle/input/mission1111/Mission/train/Tomato__Tomato_mosaic_virus/6881c9a5-04b2-41c3-b29f-1ca04bd73967___PSU_CG_2390.jpg
# /kaggle/input/mission1111/Mission/train/Tomato__Tomato_mosaic_virus/ebf036fa-436b-42aa-8a34-0b0f188bc54a___PSU_CG_2134.jpg
# /kaggle/input/mission1111/Mission/train/Tomato__Tomato_mosaic_virus/0a91f50b-1263-4b2c-a8c1-f2a6025b82f3___PSU_CG_2136.jpg
# /kaggle/input/mission1111/Mission/train/Tomato__Tomato_mosaic_virus/7d961b54-7557-4800-ae6a-00b6945f99c0___PSU_CG_2293.jpg
# /kaggle/input/mission1111/Mission/train/Tomato__Tomato_mosaic_virus/c56876f0-d18b-4a90-86d1-7f90e8e15fac___PSU_CG_2240.jpg
# /kaggle/input/mission1111/Mission/train/Tomato__Tomato_mosaic_virus/860780b3-9c8b-4f90-9010-ac255e953784___PSU_CG_2150.jpg
# /kaggle/input/mission1111/Mission/train/Tomato__Tomato_mosaic_virus/a142b58c-1713-4e17-a68c-96eaf4b5ae23___PSU_CG_2219.jpg
# /kaggle/input/mission1111/Mission/train/Tomato__Tomato_mosaic_virus/32a6609d-e858-4da0-a153-b59b4de976b7___PSU_CG_2061.jpg
# /kaggle/input/mission1111/Mission/train/Tomato__Tomato_mosaic_virus/09910ece-e505-4e19-ae9b-0d9e2eaa2cb1___PSU_CG_2047.jpg
# /kaggle/input/mission1111/Mission/train/Tomato__Tomato_mosaic_virus/db0867bf-ca5a-4dd0-99e0-6d41efaffff6___PSU_CG_2334.jpg
# /kaggle/input/mission1111/Mission/train/Tomato__Tomato_mosaic_virus/d398ca36-5b67-4690-a2d2-53380e63c4bb___PSU_CG_2085.jpg
# /kaggle/input/mission1111/Mission/train/Tomato__Tomato_mosaic_virus/9a3a36e0-b0eb-4844-84f5-db08e2d9adef___PSU_CG_2300.jpg
# /kaggle/input/mission1111/Mission/train/Tomato__Tomato_mosaic_virus/6ddf37fe-9143-420d-a269-c57f53ac5429___PSU_CG_2213.jpg
# /kaggle/input/mission1111/Mission/train/Tomato__Tomato_mosaic_virus/29bbbfcc-76ef-4506-9c1b-1a749646856e___PSU_CG_2184.jpg
# /kaggle/input/mission1111/Mission/train/Tomato__Tomato_mosaic_virus/7d688270-b9e9-41fb-a22a-6af2f6285b46___PSU_CG_2091.jpg
# /kaggle/input/mission1111/Mission/train/Tomato__Tomato_mosaic_virus/26ea2737-6f69-441b-a5da-7f68ed4e8f5e___PSU_CG_2141.jpg
# /kaggle/input/mission1111/Mission/train/Tomato__Tomato_mosaic_virus/5d5ee5fc-35e3-4be9-980e-111679ec95b3___PSU_CG_2170.jpg
# /kaggle/input/mission1111/Mission/train/Tomato__Tomato_mosaic_virus/55e25156-7b0c-43c6-b6f8-37d0b7097a38___PSU_CG_2347.jpg
# /kaggle/input/mission1111/Mission/train/Tomato__Tomato_mosaic_virus/c16122a0-a5e9-47d6-82b6-93325f1e9667___PSU_CG_2385.jpg
# /kaggle/input/mission1111/Mission/train/Tomato__Tomato_mosaic_virus/763335af-2beb-4331-b2e5-3f61a4b0b914___PSU_CG_2365.jpg
# /kaggle/input/mission1111/Mission/train/Tomato__Tomato_mosaic_virus/99a4b1cb-e55a-4954-a7c5-ebb0cc57ed2a___PSU_CG_2096.jpg
# /kaggle/input/mission1111/Mission/train/Tomato__Tomato_mosaic_virus/6065503d-0803-4697-90f7-8c7db1ee28ab___PSU_CG_2227.jpg
# /kaggle/input/mission1111/Mission/train/Tomato__Tomato_mosaic_virus/1170f108-86a3-4bc6-8a06-c82e55178f91___PSU_CG_2327.jpg
# /kaggle/input/mission1111/Mission/train/Tomato__Tomato_mosaic_virus/f5d2043f-a274-431f-accc-1a3e1a7df172___PSU_CG_2400.jpg
# /kaggle/input/mission1111/Mission/train/Tomato__Tomato_mosaic_virus/c9da2f9b-58f3-4715-8012-ee1fe722921f___PSU_CG_2199.jpg
# /kaggle/input/mission1111/Mission/train/Tomato__Tomato_mosaic_virus/5e990ddc-28f3-4624-8498-28f3b10111fd___PSU_CG_2182.jpg
# /kaggle/input/mission1111/Mission/train/Tomato__Tomato_mosaic_virus/0ce34f26-3bd6-420e-ba31-0373b465f267___PSU_CG_2099.jpg
# /kaggle/input/mission1111/Mission/train/Tomato__Tomato_mosaic_virus/2d053972-2f30-414c-9de9-e37c98e44648___PSU_CG_2104.jpg
# /kaggle/input/mission1111/Mission/train/Tomato__Tomato_mosaic_virus/2fa22081-5533-4b18-9a8f-671f210db37e___PSU_CG_2092.jpg
# /kaggle/input/mission1111/Mission/train/Tomato__Tomato_mosaic_virus/8babd25a-f124-4d1f-a57a-5db347b34f0d___PSU_CG_2355.jpg
# /kaggle/input/mission1111/Mission/train/Tomato__Tomato_mosaic_virus/ca62b320-b16a-4c41-aae6-0b9492c499f6___PSU_CG_2165.jpg
# /kaggle/input/mission1111/Mission/train/Tomato__Tomato_mosaic_virus/9ef0e7b7-ce38-4829-aad9-23b954a26000___PSU_CG_2324.jpg
# /kaggle/input/mission1111/Mission/train/Tomato__Tomato_mosaic_virus/cfd8a28f-7af7-4102-b848-0b6d1b2c60e4___PSU_CG_2404.jpg
# /kaggle/input/mission1111/Mission/train/Tomato__Tomato_mosaic_virus/6ebb483a-d1b6-4d7d-aad1-e717c2a36167___PSU_CG_2286.jpg
# /kaggle/input/mission1111/Mission/train/Tomato__Tomato_mosaic_virus/e3abcfd4-0994-4f38-a18e-83b90498d30c___PSU_CG_2297.jpg
# /kaggle/input/mission1111/Mission/train/Tomato__Tomato_mosaic_virus/0e56889c-7e80-49f3-8da3-3a437244e8fd___PSU_CG_2140.jpg
# /kaggle/input/mission1111/Mission/train/Tomato__Tomato_mosaic_virus/bfe4e207-18c5-46cb-9022-0a94c6826f81___PSU_CG_2234.jpg

# %%
# PyTorch core
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset
import torchvision
import torchvision.transforms as transforms
from torchvision import models
import cv2
import numpy as np
from PIL import Image
import albumentations as A
from albumentations.pytorch import ToTensorV2
import os
import random
import shutil
from pathlib import Path
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm import tqdm

# %%
dataset_root = Path("/kaggle/input/mission1111/Mission")

# Train and Test directories
train_dir = dataset_root / "train"
test_dir  = dataset_root / "test"

print("✅ Train folder:", train_dir)
print("✅ Test folder:", test_dir)

# Function to list classes and counts
def dataset_summary(split_dir):
    print(f"\n📂 {split_dir.name.upper()} DATASET SUMMARY")
    total_images = 0
    for class_dir in sorted(os.listdir(split_dir)):
        class_path = split_dir / class_dir
        if class_path.is_dir():
            count = len(list(class_path.glob("*.jpg"))) + len(list(class_path.glob("*.png")))
            total_images += count
            print(f"  - {class_dir}: {count} images")
    print(f"👉 Total images in {split_dir.name}: {total_images}")
    return total_images

# Print dataset details
total_train = dataset_summary(train_dir)
total_test  = dataset_summary(test_dir)

print("\n📊 OVERALL DATASET SUMMARY")
print(f"  - Total Train Images: {total_train}")
print(f"  - Total Test Images : {total_test}")
print(f"  - Grand Total       : {total_train + total_test}")

# Show one sample image from train
sample_class = sorted(os.listdir(train_dir))[0]  # pick first class alphabetically
sample_path = list((train_dir / sample_class).glob("*.jpg"))[0]

img = cv2.imread(str(sample_path))
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

plt.imshow(img)
plt.title(f"Class: {sample_class}")
plt.axis("off")
plt.show()
# Out:
# ✅ Train folder: /kaggle/input/mission1111/Mission/train
# ✅ Test folder: /kaggle/input/mission1111/Mission/test
#
# 📂 TRAIN DATASET SUMMARY
#   - Pepper__bell___Bacterial_spot: 697 images
#   - Pepper__bell___healthy: 1034 images
#   - Potato___Early_blight: 700 images
#   - Potato___Late_blight: 700 images
#   - Potato___healthy: 106 images
#   - Tomato_Bacterial_spot: 1488 images
#   - Tomato_Early_blight: 700 images
#   - Tomato_Late_blight: 1336 images
#   - Tomato_Leaf_Mold: 666 images
#   - Tomato_Septoria_leaf_spot: 1239 images
#   - Tomato_Spider_mites_Two_spotted_spider_mite: 1173 images
#   - Tomato__Target_Spot: 982 images
#   - Tomato__Tomato_YellowLeaf__Curl_Virus: 2245 images
#   - Tomato__Tomato_mosaic_virus: 261 images
#   - Tomato_healthy: 1113 images
# 👉 Total images in train: 14440
#
# 📂 TEST DATASET SUMMARY
#   - Pepper__bell___Bacterial_spot: 300 images
#   - Pepper__bell___healthy: 444 images
#   - Potato___Early_blight: 300 images
#   - Potato___Late_blight: 300 images
#   - Potato___healthy: 46 images
#   - Tomato_Bacterial_spot: 639 images
#   - Tomato_Early_blight: 300 images
#   - Tomato_Late_blight: 572 images
#   - Tomato_Leaf_Mold: 286 images
#   - Tomato_Septoria_leaf_spot: 532 images
#   - Tomato_Spider_mites_Two_spotted_spider_mite: 503 images
#   - Tomato__Target_Spot: 422 images
#   - Tomato__Tomato_YellowLeaf__Curl_Virus: 963 images
#   - Tomato__Tomato_mosaic_virus: 112 images
#   - Tomato_healthy: 477 images
# 👉 Total images in test: 6196
#
# 📊 OVERALL DATASET SUMMARY
#   - Total Train Images: 14440
#   - Total Test Images : 6196
#   - Grand Total       : 20636

# %%
# -------------------------------
#  DeepLabV3+ for background removal
# -------------------------------
deeplab = models.segmentation.deeplabv3_resnet101(pretrained=True).eval()

bg_preprocess = transforms.Compose([
    transforms.Resize((256, 256)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                         std=[0.229, 0.224, 0.225]),
])
def remove_background(img_pil):
    """Remove background using DeepLabV3+ (class 21 = plant/vegetation in COCO)."""
    input_tensor = bg_preprocess(img_pil).unsqueeze(0)
    with torch.no_grad():
        output = deeplab(input_tensor)['out'][0]
    mask = output.argmax(0).byte().cpu().numpy()
    leaf_mask = (mask != 0).astype(np.uint8) * 255
    img_cv = cv2.cvtColor(np.array(img_pil), cv2.COLOR_RGB2BGR)
    leaf_only = cv2.bitwise_and(img_cv, img_cv, mask=leaf_mask)
    return leaf_only

# -------------------------------
# 2. Custom preprocessing: Gaussian + CLAHE + resize + normalize
# -------------------------------
def custom_preprocess(img_bgr, size=(256,256)):
    # Noise cancellation
    img = cv2.GaussianBlur(img_bgr, (3,3), 0)
    
    # Contrast enhancement (CLAHE)
    lab = cv2.cvtColor(img, cv2.COLOR_BGR2LAB)
    l, a, b = cv2.split(lab)
    clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8,8))
    cl = clahe.apply(l)
    limg = cv2.merge((cl,a,b))
    img = cv2.cvtColor(limg, cv2.COLOR_LAB2BGR)
    
    # Resize
    img = cv2.resize(img, size, interpolation=cv2.INTER_AREA)
    
    # Normalize to [0,1]
    img = img.astype(np.float32) / 255.0
    return img


# -------------------------------
# 3. Albumentations transforms (augment only training)
# -------------------------------
train_aug = A.Compose([
    A.HorizontalFlip(p=0.5),
    A.VerticalFlip(p=0.5),
    A.Rotate(limit=25, p=0.5),
    A.RandomBrightnessContrast(p=0.5),
    A.Normalize(mean=(0.485, 0.456, 0.406),
                std=(0.229, 0.224, 0.225)),  # <--- ADD THIS
    ToTensorV2()
])

test_aug = A.Compose([
    A.Normalize(mean=(0.485, 0.456, 0.406),
                std=(0.229, 0.224, 0.225)),  # <--- ADD THIS
    ToTensorV2()
])


# -------------------------------
# 4. Dataset Class
# -------------------------------
class LeafDataset(Dataset):
    def __init__(self, root_dir, transform=None, use_deeplab=False):
        self.root_dir = Path(root_dir)
        self.classes = sorted([d.name for d in self.root_dir.iterdir() if d.is_dir()])
        self.samples = []
        self.transform = transform
        self.use_deeplab = use_deeplab

        for class_idx, class_name in enumerate(self.classes):
            for img_path in (self.root_dir / class_name).glob("*.jpg"):
                self.samples.append((img_path, class_idx))
            for img_path in (self.root_dir / class_name).glob("*.png"):
                self.samples.append((img_path, class_idx))

    def __len__(self):
        return len(self.samples)

    def __getitem__(self, idx):
        img_path, label = self.samples[idx]

        # Load image
        img_pil = Image.open(img_path).convert("RGB")
        img_cv = cv2.cvtColor(np.array(img_pil), cv2.COLOR_RGB2BGR)

        # 1. Optional background removal
        if self.use_deeplab:
            img_cv = remove_background(img_pil)

        # 2. Apply custom preprocessing (Gaussian + CLAHE + resize + normalize)
        img_cv = custom_preprocess(img_cv)

        # Albumentations expects numpy RGB image
        img = cv2.cvtColor((img_cv*255).astype(np.uint8), cv2.COLOR_BGR2RGB)

        # 3. Albumentations augment/transform
        if self.transform:
            img = self.transform(image=img)["image"]

        return img, label
# Out:
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=DeepLabV3_ResNet101_Weights.COCO_WITH_VOC_LABELS_V1`. You can also use `weights=DeepLabV3_ResNet101_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/deeplabv3_resnet101_coco-586e9e4e.pth" to /root/.cache/torch/hub/checkpoints/deeplabv3_resnet101_coco-586e9e4e.pth
# 100%|██████████| 233M/233M [00:01<00:00, 210MB/s]

# %%
train_dir = "/kaggle/input/mission1111/Mission/train"
test_dir  = "/kaggle/input/mission1111/Mission/test"

# Train dataset (with augmentation)
train_dataset = LeafDataset(train_dir, transform=train_aug, use_deeplab=False)
test_dataset  = LeafDataset(test_dir,  transform=test_aug,  use_deeplab=False)

# Dataloaders
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
test_loader  = DataLoader(test_dataset,  batch_size=32, shuffle=False)

# Check sample
images, labels = next(iter(train_loader))
print("Batch image tensor shape:", images.shape)
print("Batch label tensor shape:", labels.shape)
# Out:
# Batch image tensor shape: torch.Size([32, 3, 256, 256])
# Batch label tensor shape: torch.Size([32])

# %%
# Pick a random sample from train dataset
idx = random.randint(0, len(train_dataset) - 1)
img_path, label = train_dataset.samples[idx]

# Load original image
orig = cv2.imread(str(img_path))
orig_rgb = cv2.cvtColor(orig, cv2.COLOR_BGR2RGB)

# Apply preprocessing (without augmentation)
preproc_img = custom_preprocess(orig)
preproc_rgb = cv2.cvtColor((preproc_img*255).astype(np.uint8), cv2.COLOR_BGR2RGB)

# Plot original vs preprocessed
plt.figure(figsize=(10,5))

plt.subplot(1,2,1)
plt.imshow(orig_rgb)
plt.title(f"Original: {train_dataset.classes[label]}")
plt.axis("off")

plt.subplot(1,2,2)
plt.imshow(preproc_rgb)
plt.title("After Preprocessing (Gaussian + CLAHE + Resize)")
plt.axis("off")

plt.show()

# %%
    # Apply augmentation multiple times to see variations
    fig, axes = plt.subplots(1, 4, figsize=(16,4))

    for i in range(4):
        aug_img = train_aug(image=preproc_rgb)["image"]
        aug_img_np = aug_img.permute(1,2,0).cpu().numpy()
        axes[i].imshow(aug_img_np)  # ✅ direct show
        axes[i].set_title("Augmented Sample")
        axes[i].axis("off")
    plt.show()

# %%
class PlantVillageCNN(nn.Module):
    def __init__(self, num_classes=38):
        super(PlantVillageCNN, self).__init__()
        
        # Convolution Layer 1 (in_channels=3 for RGB)
        self.conv1 = nn.Conv2d(in_channels=3, out_channels=64, kernel_size=3, padding=1)  # padding=1 → same padding
        self.pool1 = nn.MaxPool2d(kernel_size=2, stride=2)  # 256 → 128
        
        # Convolution Layer 2
        self.conv2 = nn.Conv2d(in_channels=64, out_channels=32, kernel_size=3, padding=1)
        self.pool2 = nn.MaxPool2d(kernel_size=2, stride=2)  # 128 → 64 → 32 → 16
        
        # Convolution Layer 3
        self.conv3 = nn.Conv2d(in_channels=32, out_channels=32, kernel_size=3, padding=1)
        self.pool3 = nn.MaxPool2d(kernel_size=2, stride=2)  # 16 → 8 → 4
        
        # Fully Connected Layer
        self.fc1 = nn.Linear(32 * 32 * 32, 512)  # adjust size after pooling
        self.fc2 = nn.Linear(512, num_classes)
        
    def forward(self, x):
        # Conv Layer 1
        x = F.relu(self.conv1(x))
        x = self.pool1(x)
        
        # Conv Layer 2
        x = F.relu(self.conv2(x))
        x = self.pool2(x)
        
        # Conv Layer 3
        x = F.relu(self.conv3(x))
        x = self.pool3(x)
        
        # Flatten
        x = torch.flatten(x, 1)  # (batch_size, features)
        
        # Fully Connected
        x = F.relu(self.fc1(x))
        x = self.fc2(x)  # logits
        
        return x

# Test the model
model = PlantVillageCNN(num_classes=38)
print(model)
# Out:
# PlantVillageCNN(
#   (conv1): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv2): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (pool2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv3): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (pool3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (fc1): Linear(in_features=32768, out_features=512, bias=True)
#   (fc2): Linear(in_features=512, out_features=38, bias=True)
# )

# %%
def forward(self, x):
    x = F.relu(self.conv1(x)); x = self.pool1(x)
    x = F.relu(self.conv2(x)); x = self.pool2(x)
    x = F.relu(self.conv3(x)); x = self.pool3(x)
    x = torch.flatten(x, 1)
    x = F.relu(self.fc1(x))
    return self.fc2(x)

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = PlantVillageCNN(num_classes=38).to(device)

criterion = nn.CrossEntropyLoss()        # ✅ classification
optimizer = optim.Adam(model.parameters(), lr=0.001)

# %%
model = model.to(device)

# %%
# ✅ Device check
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)

# Move model to GPU
model = model.to(device)

num_epochs = 40
best_acc = 0.0   # track best test accuracy
best_epoch = 0   # track which epoch was best

for epoch in range(num_epochs):
    # ---------------- TRAIN ----------------
    model.train()
    running_loss, correct, total = 0.0, 0, 0
    
    for images, labels in tqdm(train_loader, desc=f"Epoch {epoch+1}/{num_epochs} [Train]", leave=False):
        images, labels = images.to(device, non_blocking=True), labels.to(device, non_blocking=True)
        
        # Forward
        outputs = model(images)
        loss = criterion(outputs, labels)
        
        # Backward
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        # Stats
        running_loss += loss.item()
        _, predicted = torch.max(outputs, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()
    
    train_loss = running_loss / len(train_loader)
    train_acc = 100 * correct / total
    
    # ---------------- EVAL ----------------
    model.eval()
    test_loss, correct, total = 0.0, 0, 0
    with torch.no_grad():
        for images, labels in tqdm(test_loader, desc=f"Epoch {epoch+1}/{num_epochs} [Test]", leave=False):
            images, labels = images.to(device, non_blocking=True), labels.to(device, non_blocking=True)
            outputs = model(images)
            loss = criterion(outputs, labels)
            
            test_loss += loss.item()
            _, predicted = torch.max(outputs, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
    
    test_loss /= len(test_loader)
    test_acc = 100 * correct / total
    
    # ---------------- LOGGING ----------------
    print(f"Epoch [{epoch+1}/{num_epochs}] "
          f"Train Loss: {train_loss:.4f}, Train Acc: {train_acc:.2f}% | "
          f"Test Loss: {test_loss:.4f}, Test Acc: {test_acc:.2f}%")
    
    # ---------------- SAVE BEST MODEL ----------------
    if test_acc > best_acc:
        best_acc = test_acc
        best_epoch = epoch + 1
        torch.save(model.state_dict(), "best_plantvillage_cnn.pth")
        print(f"💾 Saved new best model at epoch {best_epoch} with Test Acc: {best_acc:.2f}%")

print(f"\n✅ Training complete! Best epoch = {best_epoch}, Best Test Acc = {best_acc:.2f}%")

# ✅ After training, check GPU usage
# !nvidia-smi
# Out:
# Using device: cuda
# Epoch [1/40] Train Loss: 1.2903, Train Acc: 58.12% | Test Loss: 0.8313, Test Acc: 71.66%
# 💾 Saved new best model at epoch 1 with Test Acc: 71.66%
# Epoch [2/40] Train Loss: 0.6066, Train Acc: 79.76% | Test Loss: 0.4432, Test Acc: 85.39%
# 💾 Saved new best model at epoch 2 with Test Acc: 85.39%
# Epoch [3/40] Train Loss: 0.4323, Train Acc: 85.51% | Test Loss: 0.3186, Test Acc: 89.20%
# 💾 Saved new best model at epoch 3 with Test Acc: 89.20%
# Epoch [4/40] Train Loss: 0.3514, Train Acc: 88.05% | Test Loss: 0.2945, Test Acc: 89.82%
# 💾 Saved new best model at epoch 4 with Test Acc: 89.82%
# Epoch [5/40] Train Loss: 0.2927, Train Acc: 90.13% | Test Loss: 0.2590, Test Acc: 91.24%
# 💾 Saved new best model at epoch 5 with Test Acc: 91.24%
# Epoch [6/40] Train Loss: 0.2567, Train Acc: 91.37% | Test Loss: 0.2875, Test Acc: 90.67%
# Epoch [7/40] Train Loss: 0.2331, Train Acc: 92.16% | Test Loss: 0.2054, Test Acc: 92.53%
# 💾 Saved new best model at epoch 7 with Test Acc: 92.53%
# Epoch [8/40] Train Loss: 0.2117, Train Acc: 92.83% | Test Loss: 0.2812, Test Acc: 90.99%
# Epoch [9/40] Train Loss: 0.1927, Train Acc: 93.46% | Test Loss: 0.2114, Test Acc: 92.88%
# 💾 Saved new best model at epoch 9 with Test Acc: 92.88%
# Epoch [10/40] Train Loss: 0.1797, Train Acc: 94.06% | Test Loss: 0.1974, Test Acc: 93.64%
# 💾 Saved new best model at epoch 10 with Test Acc: 93.64%
# Epoch [11/40] Train Loss: 0.1669, Train Acc: 94.40% | Test Loss: 0.2160, Test Acc: 93.11%
# Epoch [12/40] Train Loss: 0.1740, Train Acc: 94.34% | Test Loss: 0.2652, Test Acc: 91.51%
# Epoch [13/40] Train Loss: 0.1498, Train Acc: 94.97% | Test Loss: 0.2251, Test Acc: 93.38%
# Epoch [14/40] Train Loss: 0.1340, Train Acc: 95.64% | Test Loss: 0.2021, Test Acc: 93.96%
# 💾 Saved new best model at epoch 14 with Test Acc: 93.96%
# Epoch [15/40] Train Loss: 0.1580, Train Acc: 94.69% | Test Loss: 0.1727, Test Acc: 94.59%
# 💾 Saved new best model at epoch 15 with Test Acc: 94.59%
# Epoch [16/40] Train Loss: 0.1166, Train Acc: 96.22% | Test Loss: 0.1344, Test Acc: 95.67%
# 💾 Saved new best model at epoch 16 with Test Acc: 95.67%
# Epoch [17/40] Train Loss: 0.1278, Train Acc: 95.92% | Test Loss: 0.1458, Test Acc: 95.48%
# Epoch [18/40] Train Loss: 0.1160, Train Acc: 96.14% | Test Loss: 0.1722, Test Acc: 94.58%
# Epoch [19/40] Train Loss: 0.1213, Train Acc: 96.19% | Test Loss: 0.2211, Test Acc: 93.37%
# Epoch [20/40] Train Loss: 0.1121, Train Acc: 96.39% | Test Loss: 0.1391, Test Acc: 95.26%
# Epoch [21/40] Train Loss: 0.1042, Train Acc: 96.66% | Test Loss: 0.1943, Test Acc: 94.53%
# Epoch [22/40] Train Loss: 0.1081, Train Acc: 96.46% | Test Loss: 0.1667, Test Acc: 94.61%
# Epoch [23/40] Train Loss: 0.0985, Train Acc: 96.64% | Test Loss: 0.1945, Test Acc: 94.54%
# Epoch [24/40] Train Loss: 0.1187, Train Acc: 96.41% | Test Loss: 0.1296, Test Acc: 95.80%
# 💾 Saved new best model at epoch 24 with Test Acc: 95.80%
# Epoch [25/40] Train Loss: 0.0878, Train Acc: 97.06% | Test Loss: 0.2026, Test Acc: 94.66%
# Epoch [26/40] Train Loss: 0.1113, Train Acc: 96.40% | Test Loss: 0.1728, Test Acc: 95.53%
# Epoch [27/40] Train Loss: 0.1018, Train Acc: 96.81% | Test Loss: 0.1381, Test Acc: 96.11%
# 💾 Saved new best model at epoch 27 with Test Acc: 96.11%
# Epoch [28/40] Train Loss: 0.0936, Train Acc: 96.96% | Test Loss: 0.1802, Test Acc: 94.88%
# Epoch [29/40] Train Loss: 0.1085, Train Acc: 96.64% | Test Loss: 0.3803, Test Acc: 89.95%
# Epoch [30/40] Train Loss: 0.0884, Train Acc: 97.21% | Test Loss: 0.1659, Test Acc: 95.05%
# Epoch [31/40] Train Loss: 0.0873, Train Acc: 97.25% | Test Loss: 0.1763, Test Acc: 95.08%
# Epoch [32/40] Train Loss: 0.0795, Train Acc: 97.38% | Test Loss: 0.1715, Test Acc: 95.42%
# Epoch [33/40] Train Loss: 0.0821, Train Acc: 97.23% | Test Loss: 0.1601, Test Acc: 95.48%
# Epoch [34/40] Train Loss: 0.0891, Train Acc: 97.22% | Test Loss: 0.1453, Test Acc: 95.63%
# Epoch [35/40] Train Loss: 0.0739, Train Acc: 97.66% | Test Loss: 0.1912, Test Acc: 94.51%
# Epoch [36/40] Train Loss: 0.0782, Train Acc: 97.45% | Test Loss: 0.1392, Test Acc: 95.98%
# Epoch [37/40] Train Loss: 0.0862, Train Acc: 97.30% | Test Loss: 0.1472, Test Acc: 96.17%
# 💾 Saved new best model at epoch 37 with Test Acc: 96.17%
# Epoch [38/40] Train Loss: 0.0760, Train Acc: 97.69% | Test Loss: 0.1899, Test Acc: 95.06%
# Epoch [39/40] Train Loss: 0.0632, Train Acc: 98.00% | Test Loss: 0.1889, Test Acc: 95.19%
# Epoch [40/40] Train Loss: 0.0713, Train Acc: 97.78% | Test Loss: 0.1714, Test Acc: 95.42%
#
# ✅ Training complete! Best epoch = 37, Best Test Acc = 96.17%
# Wed Sep 17 21:45:44 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 560.35.03              Driver Version: 560.35.03      CUDA Version: 12.6     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla P100-PCIE-16GB           Off |   00000000:00:04.0 Off |                    0 |
# | N/A   43C    P0             32W /  250W |    2837MiB /  16384MiB |     10%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# +-----------------------------------------------------------------------------------------+

# %%
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# -------------------------------
# EVALUATE FULL TEST SET
# -------------------------------
model.eval()
all_labels = []
all_preds = []

with torch.no_grad():
    for images, labels in test_loader:
        images, labels = images.to(device), labels.to(device)
        outputs = model(images)
        _, predicted = torch.max(outputs, 1)
        
        all_labels.extend(labels.cpu().numpy())
        all_preds.extend(predicted.cpu().numpy())

# ✅ Class names (same order as dataset)
class_names = test_dataset.classes

# 📊 Classification Report
print("📊 Classification Report:")
print(classification_report(all_labels, all_preds, target_names=class_names))

# 📊 Confusion Matrix (raw counts)
cm = confusion_matrix(all_labels, all_preds)

plt.figure(figsize=(14,12))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues",
            xticklabels=class_names, yticklabels=class_names,
            cbar_kws={'label': 'Count'})
plt.xlabel("Predicted")
plt.ylabel("True")
plt.title("Confusion Matrix (Counts)")
plt.show()

# 📊 Normalized Confusion Matrix (per-class %)
cm_normalized = cm.astype("float") / cm.sum(axis=1)[:, np.newaxis]

plt.figure(figsize=(14,12))
sns.heatmap(cm_normalized, annot=True, fmt=".2f", cmap="Blues",
            xticklabels=class_names, yticklabels=class_names,
            cbar_kws={'label': 'Proportion'})
plt.xlabel("Predicted")
plt.ylabel("True")
plt.title("Normalized Confusion Matrix (per class %)")
plt.show()
# Out:
# 📊 Classification Report:
#                                              precision    recall  f1-score   support
#
#               Pepper__bell___Bacterial_spot       0.95      0.97      0.96       300
#                      Pepper__bell___healthy       1.00      0.95      0.97       444
#                       Potato___Early_blight       0.95      0.99      0.97       300
#                        Potato___Late_blight       0.92      0.94      0.93       300
#                            Potato___healthy       0.76      0.98      0.86        46
#                       Tomato_Bacterial_spot       0.98      0.97      0.97       639
#                         Tomato_Early_blight       0.93      0.84      0.88       300
#                          Tomato_Late_blight       0.98      0.91      0.94       572
#                            Tomato_Leaf_Mold       0.96      0.93      0.95       286
#                   Tomato_Septoria_leaf_spot       0.97      0.91      0.94       532
# Tomato_Spider_mites_Two_spotted_spider_mite       0.95      0.95      0.95       503
#                         Tomato__Target_Spot       0.83      0.98      0.90       422
#       Tomato__Tomato_YellowLeaf__Curl_Virus       0.97      0.99      0.98       963
#                 Tomato__Tomato_mosaic_virus       0.96      0.97      0.97       112
#                              Tomato_healthy       0.99      0.99      0.99       477
#
#                                    accuracy                           0.95      6196
#                                   macro avg       0.94      0.95      0.94      6196
#                                weighted avg       0.96      0.95      0.95      6196
